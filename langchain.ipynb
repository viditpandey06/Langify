# %%
from langchain_openai import OpenAI

# %%
import os
import API_KEY_VALUES
os.environ["OPEN_API_KEY"]=API_KEY_VALUES.OPEN_AI_KEY

# %%
llm=OpenAI(openai_api_key=os.environ["OPEN_API_KEY"],temperature=0.6)

# %% [markdown]
# Temprature variable is used the set the creativity of the answer generated by the model. Ranges between 0 to 1.

# %%
text="What is the meaning of life"
print(llm.predict(text))

# %%
llm.predict("can you tell me the meaning of life?")

# %%
import API_KEY_VALUES
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]=API_KEY_VALUES.HUGGINGFACE_AI_KEY
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 3
#       1 import API_KEY_VALUES
#       2 import os
# ----> 3 os.environ["HUGGINGFACEHUB_API_TOKEN"]=API_KEY_VALUES.HUGGINGFACE_AI_KEY
#
# AttributeError: module 'API_KEY_VALUES' has no attribute 'HUGGINGFACE_AI_KEY'

# %%
from langchain import HuggingFaceHub
llm_huggingface=HuggingFaceHub(repo_id="google/flan-t5-large",model_kwargs={"temperature":0.6,"max_length":100})

# %%
output=llm_huggingface.predict("where is statue of liberty")
print(output)
# Out:
# london
